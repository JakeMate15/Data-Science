# %% [markdown]
# # Práctica No. 10: Aplicando K-Means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

paises = pd.read_csv('infoPaises.csv', index_col = 0)
paises
# Out:
#                              Income Group  \
# Short Name
# Afghanistan                    Low income
# Angola                Lower middle income
# Albania               Upper middle income
# United Arab Emirates          High income
# Argentina             Upper middle income
# ...                                   ...
# Samoa                 Lower middle income
# Yemen                          Low income
# South Africa          Upper middle income
# Zambia                Lower middle income
# Zimbabwe              Lower middle income
#
#                       CO2 emissions (metric tons per capita)  \
# Short Name
# Afghanistan                                         0.223479
# Angola                                              0.592743
# Albania                                             1.544550
# United Arab Emirates                               20.252272
# Argentina                                           3.405618
# ...                                                      ...
# Samoa                                               0.960782
# Yemen                                               0.308515
# South Africa                                        6.687563
# Zambia                                              0.401903
# Zimbabwe                                            0.530484
#
#                       GDP per capita (current US$)  \
# Short Name
# Afghanistan                             516.866797
# Angola                                 1502.950754
# Albania                                5343.037704
# United Arab Emirates                  37629.174168
# Argentina                              8496.428157
# ...                                            ...
# Samoa                                  4042.722715
# Yemen                                   583.875663
# South Africa                           5741.641249
# Zambia                                  956.831747
# Zimbabwe                               1372.696674
#
#                       Life expectancy at birth, total (years)
# Short Name
# Afghanistan                                            62.575
# Angola                                                 62.261
# Albania                                                76.989
# United Arab Emirates                                   78.946
# Argentina                                              75.892
# ...                                                       ...
# Samoa                                                  72.768
# Yemen                                                  64.650
# South Africa                                           65.252
# Zambia                                                 62.380
# Zimbabwe                                               61.124
#
# [185 rows x 4 columns]

# %%
co2 = paises['CO2 emissions (metric tons per capita)']
# Out:
# Short Name
# Afghanistan              0.223479
# Angola                   0.592743
# Albania                  1.544550
# United Arab Emirates    20.252272
# Argentina                3.405618
#                           ...
# Samoa                    0.960782
# Yemen                    0.308515
# South Africa             6.687563
# Zambia                   0.401903
# Zimbabwe                 0.530484
# Name: CO2 emissions (metric tons per capita), Length: 185, dtype: float64
