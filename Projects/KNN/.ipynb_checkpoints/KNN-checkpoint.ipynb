# %% [markdown]
# # Practica 8 KNN

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from matplotlib.patches import Patch

# %% [markdown]
# ## Procesamiento de Datos

# %%
# Lectura de los datos de países
codigo_paises = pd.read_csv('WDICountry.csv', usecols=['Country Code', 'Short Name', 'Income Group'])
info_paises = pd.read_csv('WDICSV.csv', usecols=['Country Code', 'Indicator Name', '2020'])

# Indicadores de interés
indicadoresInteres = ['Life expectancy at birth, total (years)', 'CO2 emissions (metric tons per capita)', 'GDP per capita (current US$)']
info_paises_filtrado = info_paises[info_paises['Indicator Name'].isin(indicadoresInteres)]

# Obtener un solo dataframe con la informacion de interes
info_paises_pivot = info_paises_filtrado.pivot(index='Country Code', columns='Indicator Name', values='2020')
df_combinado = codigo_paises.merge(info_paises_pivot, on='Country Code', how='left')

# Limpiar datos nulos y establecer la columna indice
df_combinado = df_combinado.set_index('Country Code').dropna()

df_combinado
# Out:
#                         Short Name         Income Group  \
# Country Code
# AFG                    Afghanistan           Low income
# AGO                         Angola  Lower middle income
# ALB                        Albania  Upper middle income
# ARE           United Arab Emirates          High income
# ARG                      Argentina  Upper middle income
# ...                            ...                  ...
# WSM                          Samoa  Lower middle income
# YEM                          Yemen           Low income
# ZAF                   South Africa  Upper middle income
# ZMB                         Zambia  Lower middle income
# ZWE                       Zimbabwe  Lower middle income
#
#               CO2 emissions (metric tons per capita)  \
# Country Code
# AFG                                         0.223479
# AGO                                         0.592743
# ALB                                         1.544550
# ...

# %%
df_combinado.to_csv('infoPaises.csv', index=False)

# %% [markdown]
# ## Visualizar los datos

# %%
# Scatter plot para CO2 vs PIB per capita
plt.figure(figsize=(14, 6))

# Primer subplot
plt.subplot(1, 3, 1)
for group in df_combinado['Income Group'].unique():
    subset = df_combinado[df_combinado['Income Group'] == group]
    plt.scatter(subset['GDP per capita (current US$)'], subset['CO2 emissions (metric tons per capita)'], label=group, alpha=0.6)
plt.xlabel('PIB per cápita')
plt.ylabel('Emisiones CO2 per cápita')
plt.title('PIB per cápita vs Emisiones CO2')
plt.legend()

# Scatter plot para PIB per capita vs Esperanza de vida
plt.subplot(1, 3, 3)
for group in df_combinado['Income Group'].unique():
    subset = df_combinado[df_combinado['Income Group'] == group]
    plt.scatter(subset['GDP per capita (current US$)'], subset['Life expectancy at birth, total (years)'], label=group, alpha=0.6)
plt.xlabel('PIB per cápita')
plt.ylabel('Esperanza de vida en años')
plt.title('PIB per capita vs Esperanza de vida')
plt.legend()


plt.tight_layout()
plt.show()

# %%
# Crear una figura 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Definir colores para cada grupo de 'Income Group'
colors = {'High income': 'b', 'Upper middle income': 'y', 'Lower middle income': 'g', 'Low income': 'r'}

# Iterar a través de cada grupo y graficar sus puntos en el espacio 3D
for group, color in colors.items():
    subset = df_combinado[df_combinado['Income Group'] == group]
    ax.scatter(subset['CO2 emissions (metric tons per capita)'],
               subset['GDP per capita (current US$)'],
               subset['Life expectancy at birth, total (years)'],
               label=group,
               c=color,
               alpha=0.6)

# Etiquetas de los ejes
ax.set_xlabel('Emisiones de CO2')
ax.set_ylabel('PIB per capita')
ax.set_zlabel('Esperanza de vida')

# Leyenda
ax.legend()

# Mostrar el gráfico interactivo
plt.show()

# %% [markdown]
# ## Conjunto de pruebas

# %%
# Obtener el conjunto de pruebas
conjunto_de_pruebas = df_combinado.sample(n=20)
df_combinado = df_combinado.drop(conjunto_de_pruebas.index)
conjunto_de_pruebas[:]
# Out:
#                                   Short Name         Income Group  \
# Country Code
# SLB                          Solomon Islands  Lower middle income
# DOM                       Dominican Republic  Upper middle income
# SWE                                   Sweden          High income
# PRT                                 Portugal          High income
# ISL                                  Iceland          High income
# GAB                                    Gabon  Upper middle income
# NER                                    Niger           Low income
# TZA                                 Tanzania  Lower middle income
# LVA                                   Latvia          High income
# LTU                                Lithuania          High income
# KEN                                    Kenya  Lower middle income
# IND                                    India  Lower middle income
# ARE                     United Arab Emirates          High income
# ...

# %% [markdown]
# ## Implementacion de KNN

# %%
# Asumiendo que df_combinado y conjunto_de_pruebas son tus DataFrames de entrenamiento y prueba

# Preparar los datos
entrenamientoX = df_combinado[['CO2 emissions (metric tons per capita)', 'GDP per capita (current US$)', 'Life expectancy at birth, total (years)']]
entrenamientoY = df_combinado['Income Group']
pruebasX = conjunto_de_pruebas[['CO2 emissions (metric tons per capita)', 'GDP per capita (current US$)', 'Life expectancy at birth, total (years)']]
pruebasY = conjunto_de_pruebas['Income Group']

# Crear un mapeo de categorías a colores
categoriasUnicas = entrenamientoY.unique()
colores = plt.cm.rainbow(np.linspace(0, 1, len(categoriasUnicas)))
colorCategorias = {categoria: color for categoria, color in zip(categoriasUnicas, colores)}

# Definir el rango de valores de K para probar
ks = range(1, 11) 

# Crear una figura y un conjunto de subgráficas
fig, axs = plt.subplots(5, 2, figsize=(30, 40), subplot_kw={'projection': '3d'}) 

# Aplanar el arreglo de subgráficas para facilitar su acceso
axs = axs.flatten()

# Probar diferentes valores de K y crear gráficas
for idx, k in enumerate(ks):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(entrenamientoX, entrenamientoY)
    prediccion = knn.predict(pruebasX)

    ax = axs[idx]

    # Dibujar todos los puntos de prueba
    leyenda_parches = [Patch(color=colorCategorias[categoria], label=categoria) for categoria in categoriasUnicas]
    for categoria in categoriasUnicas:
        mascaraCategoria = pruebasY == categoria
        ax.scatter(pruebasX.loc[mascaraCategoria, 'CO2 emissions (metric tons per capita)'],
                   pruebasX.loc[mascaraCategoria, 'GDP per capita (current US$)'],
                   pruebasX.loc[mascaraCategoria, 'Life expectancy at birth, total (years)'],
                   color=colorCategorias[categoria], alpha=0.35, marker='o', label=f'Real - {categoria}')

    # Resaltar predicciones incorrectas
    mascaraIncorrecta = prediccion != pruebasY
    ax.scatter(pruebasX.loc[mascaraIncorrecta, 'CO2 emissions (metric tons per capita)'],
               pruebasX.loc[mascaraIncorrecta, 'GDP per capita (current US$)'],
               pruebasX.loc[mascaraIncorrecta, 'Life expectancy at birth, total (years)'],
               color='black', alpha=1, marker='x', label='Predicción incorrecta')

    ax.set_xlabel('Emisiones CO2')
    ax.set_ylabel('PIB per capita')
    ax.set_zlabel('Esperanza de vida')
    precision = accuracy_score(pruebasY, prediccion)
    ax.set_title(f'K={k}, Precisión: {precision:.2f}')
     # Añadir la leyenda personalizada
    leyenda_parches_actual = list(leyenda_parches)  # Copia la leyenda base
    leyenda_parches_actual.append(Patch(color='black', label='Predicción incorrecta'))  # Añade el parche para la predicción incorrecta
    ax.legend(handles=leyenda_parches_actual, loc='upper right')


# Ajustar el espacio entre las gráficas
plt.subplots_adjust(wspace= -.7, hspace=0.4)

# Mostrar la figura
plt.show()
