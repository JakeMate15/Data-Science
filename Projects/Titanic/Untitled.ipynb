# %% [markdown]
# # Titanic

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar los datos
df = pd.read_csv('train.csv')
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Edad promedio de los pasajeros:

# %%
# Obtener edades
edades = df['Age']

# Calcular la edad promedio
edadPromedio = edades.mean()
print("Edad promedio de los pasajeros:", average_age)

# Graficar las diferentes edades
plt.hist(edades, bins = 10)

plt.xlabel = 'Edad'


plt.show()
# Out:
# Edad promedio de los pasajeros: 30.272590361445783

# %% [markdown]
# ## Relación entre la edad y la clase del ticket:

# %%
# Visualizar la relación entre la edad y la clase del pasaje
sns.boxplot(x='Pclass', y='Age', data=df)
plt.show()

# %% [markdown]
# ## Relación entre las tarifas pagadas y la supervivencia de los pasajeros:

# %%
# Visualizar la relación entre tarifa y supervivencia
sns.barplot(x='Survived', y='Fare', data=df)
plt.show()

# %% [markdown]
# ## Cantidad de pasajeros que viajaban solos y la diferencia en la supervivencia

# %%
# Crear una nueva columna para identificar a los pasajeros que viajaban solos
df['Alone'] = (df['SibSp'] + df['Parch']) == 0

# Comparar la tasa de supervivencia entre los que viajaban solos y los que no
sns.barplot(x='Alone', y='Survived', data=df)
plt.show()

# %% [markdown]
# ## Cantidad de familias a bordo y patrones de supervivencia

# %%
# Contar el número de familias
family_count = df[df['Parch'] > 0]['Parch'].count()

# Explorar la supervivencia de las familias
sns.barplot(x='Parch', y='Survived', data=df)
plt.show()

# %% [markdown]
# ## Columnas con valores nulos y cómo manejarlos

# %%
# Encontrar columnas con valores nulos
null_columns = df.isnull().sum()

# Imprimir columnas con valores nulos
print(null_columns[null_columns > 0])

# Estrategias para manejar valores nulos (ejemplo: llenar valores nulos en 'Age')
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64
